# %%
import os
import glob
import torch
import numpy as np
import tifffile
import shutil
import torch.nn as nn

IMAGES_DIR = "min_results"     # Folder for results
LABELS_MANUAL = "min_mask_1"   # Manually Labeled mask (with 1,3,0)
PRED_MASKS = "pred_mask_1"     # Output folder
MODEL_PATH = "model_iter_inout.pt"  

os.makedirs(PRED_MASKS, exist_ok=True)

# -- Two channel net (0 -> in focus, 1 -> out of focus)
class Simple2ClassNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 16, 3, padding=1)
        self.conv2 = nn.Conv2d(16, 2, 3, padding=1)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        x = self.relu(self.conv1(x))
        x = self.conv2(x)
        return x  # logits => shape [B,2,H,W]

device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")

model = Simple2ClassNet().to(device)
model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
model.eval()

def infer_mask(img_path):
    """
    Inference of net with 2 channel
      - channel 0 => "in focus" => output label=1
      - channel 1 => "out of focus" => output label=3
    """
    img = tifffile.imread(img_path)
    if img.ndim == 3:
        img = img[..., 0]
    img = img.astype(np.float32)
    if img.max() > 1:
        img /= 255.0

    img_tensor = torch.from_numpy(img).unsqueeze(0).unsqueeze(0).to(device)
    with torch.no_grad():
        logits = model(img_tensor)  # [1,2,H,W]
        probs = torch.softmax(logits, dim=1)
        pred_class = probs.argmax(dim=1).squeeze(0).cpu().numpy()  # (H,W) in {0,1}

    # Mapping 0->1, 1->3
    out_mask = np.where(pred_class == 0, 1, 3).astype(np.uint8)
    return out_mask

def main():
    all_imgs = sorted(glob.glob(os.path.join(IMAGES_DIR, "*.tiff")))
    print(f"Finding {len(all_imgs)} images in '{IMAGES_DIR}'...")

    for img_path in all_imgs:
        fname = os.path.basename(img_path)
        label_manual = os.path.join(LABELS_MANUAL, fname)
        label_pred = os.path.join(PRED_MASKS, fname)

        if os.path.exists(label_manual):
            # 1) Reading the manually labeled mask 
            manual_mask = tifffile.imread(label_manual).astype(np.uint8)
            # 2) Inference 
            model_mask = infer_mask(img_path)

            # 3) Componing the full mask: if manual_mask[y,x] in {1,3} then leave manual, otherwise model_mask[y,x]
            final_mask = np.where(manual_mask == 0, model_mask, manual_mask)

            # Saving the image
            tifffile.imwrite(label_pred, final_mask)
            print(f"[DONE] {fname} -> {PRED_MASKS}/ (manual + model)")
        else:
            # Otherwise, pure inference
            out_mask = infer_mask(img_path)
            tifffile.imwrite(label_pred, out_mask)
            print(f"[INF] {fname} -> {PRED_MASKS}/ (predicted mask)")

if __name__ == "__main__":
    main()
# Out:
# Finding 100 images in 'min_results'...
# [INF] variance_image_0_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_10_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_11_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_12_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_13_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_14_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_15_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_16_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_17_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_18_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_19_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_1_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [DONE] variance_image_20_min_grayscale.tiff -> pred_mask_1/ (manual + model)
# [INF] variance_image_21_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_22_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_23_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_24_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_25_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_26_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_27_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_28_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_29_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_2_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [DONE] variance_image_30_min_grayscale.tiff -> pred_mask_1/ (manual + model)
# [INF] variance_image_31_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_32_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_33_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_34_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_35_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_36_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_37_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_38_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_39_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_3_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [DONE] variance_image_40_min_grayscale.tiff -> pred_mask_1/ (manual + model)
# [INF] variance_image_41_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_42_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_43_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_44_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_45_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_46_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_47_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_48_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_49_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_4_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [DONE] variance_image_50_min_grayscale.tiff -> pred_mask_1/ (manual + model)
# [INF] variance_image_51_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_52_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_53_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_54_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_55_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_56_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_57_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_58_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_59_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_5_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_60_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_61_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_62_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_63_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_64_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_65_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_66_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_67_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_68_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_69_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_6_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_70_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_71_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_72_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_73_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_74_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_75_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_76_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_77_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_78_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_79_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_7_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_80_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_81_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_82_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_83_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_84_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_85_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_86_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_87_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_88_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_89_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_8_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_90_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_91_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_92_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_93_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_94_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_95_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_96_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_97_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_98_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_99_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
# [INF] variance_image_9_min_grayscale.tiff -> pred_mask_1/ (predicted mask)
